# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# # 1) Encontrar carpeta data/raw

# %%
RAW = (Path.cwd().parent / "data" / "raw")
if not RAW.exists():
    base = Path.cwd()
    for c in [base] + list(base.parents):
        d = c / "data" / "raw"
        if d.exists():
            RAW = d
            break

print(RAW.resolve())
# Out:
# C:\Users\cubea\OneDrive\Escritorio\project_esports_occidente\data\raw

# %% [markdown]
# # 2) Lector

# %%
def lee(p):
    try:
        return pd.read_csv(p, encoding="utf-8", low_memory=False)
    except UnicodeDecodeError:
        return pd.read_csv(p, encoding="latin-1", low_memory=False)

# %% [markdown]
# # 3) Carga de ficheros

# %%
twitch_game       = lee(RAW / "Twitch_game_data.csv")
twitch_global     = lee(RAW / "Twitch_global_data.csv")
general_esport    = lee(RAW / "GeneralEsportData.csv")
historical_esport = lee(RAW / "HistoricalEsportData.csv")

# %%
def vista_previa(df, nombre, n=3):
    print("\n",nombre)
    display(df.head(n))  

vista_previa(twitch_game, "twitch_game")
vista_previa(twitch_global, "twitch_global")
vista_previa(general_esport, "general_esport")
vista_previa(historical_esport, "historical_esport")
# Out:
#  twitch_game
#    Rank                              Game  Month  Year  Hours_watched  \
# 0     1                 League of Legends      1  2016       94377226
# 1     2  Counter-Strike: Global Offensive      1  2016       47832863
# 2     3                            Dota 2      1  2016       45185893
#
#    Hours_streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0         1362044        530270           2903     129172       127021
# 1          830105        372654           2197     120849        64378
# 2          433397        315083           1100      44074        60815
#
#    Avg_channels  Avg_viewer_ratio
# 0          1833             69.29
# 1          1117             57.62
# 2           583            104.26
#  twitch_global
#    year  Month  Hours_watched  Avg_viewers  Peak_viewers  Streams  \
# 0  2016      1      480241904       646355       1275257  7701675
# 1  2016      2      441859897       635769       1308032  7038520
# 2  2016      3      490669308       660389       1591551  7390957
#
#    Avg_channels  Games_streamed  Viewer_ratio
# 0         20076           12149         29.08
# 1         20427           12134         28.98
# 2         20271           12234         28.92
#  general_esport
#                  Game  ReleaseDate     Genre TotalEarnings OfflineEarnings  \
# 0      Age of Empires         1997  Strategy     736284.75       522378.17
# 1   Age of Empires II         1999  Strategy    3898508.73      1361409.22
# 2  Age of Empires III         2005  Strategy     122256.72         44472.6
#
#    PercentOffline  TotalPlayers  TotalTournaments
# 0        0.709478           624               341
# 1        0.349213          2256              1939
# 2        0.363764           172               179
#  historical_esport
#          Date                          Game  Earnings  Players  Tournaments
# 0  1998-01-01  Command & Conquer: Red Alert   15000.0        8            1
# 1  1998-01-01                    QuakeWorld   15000.0        8            1
# 2  1998-05-01                      Quake II   15000.0        4            1

# %%
tg = twitch_game.rename(columns={
    "Game":"game","Year":"year","Month":"month",
    "Hours_watched":"hours_watched","Hours_streamed":"hours_streamed",
    "Peak_viewers":"peak_viewers","Avg_viewers":"avg_viewers",
    "Peak_channels":"peak_channels","Avg_channels":"avg_channels",
    "Streamers":"streamers","Avg_viewer_ratio":"avg_viewer_ratio",
    "Rank":"rank"
}).copy()

tg["game"] = tg["game"].astype(str).str.strip()
tg["game_key"] = tg["game"].str.lower().str.strip()
tg["year"] = tg["year"].astype(int)
tg["month"] = tg["month"].astype(int)
tg["year_month"] = pd.to_datetime(tg["year"].astype(str)+"-"+tg["month"].astype(str)+"-01")


print( tg.shape)
display(tg.head(3))
# Out:
# (21000, 14)
#    rank                              game  month  year  hours_watched  \
# 0     1                 League of Legends      1  2016       94377226
# 1     2  Counter-Strike: Global Offensive      1  2016       47832863
# 2     3                            Dota 2      1  2016       45185893
#
#    hours_streamed  peak_viewers  peak_channels  streamers  avg_viewers  \
# 0         1362044        530270           2903     129172       127021
# 1          830105        372654           2197     120849        64378
# 2          433397        315083           1100      44074        60815
#
#    avg_channels  avg_viewer_ratio                          game_key year_month
# 0          1833             69.29                 league of legends 2016-01-01
# 1          1117             57.62  counter-strike: global offensive 2016-01-01
# 2           583            104.26                            dota 2 2016-01-01

# %%
he = historical_esport.rename(columns={
    "Game":"game","Date":"date",
    "Earnings":"year_prize_usd","Players":"year_players","Tournaments":"year_tournaments"
}).copy()

he["game"] = he["game"].astype(str).str.strip()
he["game_key"] = he["game"].str.lower().str.strip()


he["year"] = pd.to_datetime(he["date"], errors="coerce").dt.year
he = he.dropna(subset=["year"])
he["year"] = he["year"].astype(int)

he["year_prize_usd"]   = pd.to_numeric(he["year_prize_usd"].astype(str).str.replace(",", ""), errors="coerce")
he["year_players"]     = pd.to_numeric(he["year_players"], errors="coerce")
he["year_tournaments"] = pd.to_numeric(he["year_tournaments"], errors="coerce")

print(he.shape)
display(he.head(3))
# Out:
# (10239, 7)
#          date                          game  year_prize_usd  year_players  \
# 0  1998-01-01  Command & Conquer: Red Alert         15000.0             8
# 1  1998-01-01                    QuakeWorld         15000.0             8
# 2  1998-05-01                      Quake II         15000.0             4
#
#    year_tournaments                      game_key  year
# 0                 1  command & conquer: red alert  1998
# 1                 1                    quakeworld  1998
# 2                 1                      quake ii  1998

# %%
ge = general_esport.rename(columns={
    "Game":"game","ReleaseDate":"release_date","Genre":"genre",
    "TotalEarnings":"total_prize_usd","OfflineEarnings":"offline_prize_usd",
    "PercentOffline":"pct_offline_prize","TotalPlayers":"total_players",
    "TotalTournaments":"total_tournaments"
}).copy()

ge["game"] = ge["game"].astype(str).str.strip()
ge["game_key"] = ge["game"].str.lower().str.strip()

for c in ["total_prize_usd","offline_prize_usd","pct_offline_prize","total_players","total_tournaments"]:
    if c in ge.columns:
        ge[c] = pd.to_numeric(ge[c], errors="coerce")

print( ge.shape)
display(ge.head(3))
# Out:
# (669, 9)
#                  game  release_date     genre  total_prize_usd  \
# 0      Age of Empires          1997  Strategy        736284.75
# 1   Age of Empires II          1999  Strategy       3898508.73
# 2  Age of Empires III          2005  Strategy        122256.72
#
#    offline_prize_usd  pct_offline_prize  total_players  total_tournaments  \
# 0          522378.17           0.709478            624                341
# 1         1361409.22           0.349213           2256               1939
# 2           44472.60           0.363764            172                179
#
#              game_key
# 0      age of empires
# 1   age of empires ii
# 2  age of empires iii

# %%
# 1) Seleccionar solo las columnas necesarias de cada DF para el merge
he_sel = he[["game_key","year","year_prize_usd","year_players","year_tournaments"]].copy()
ge_sel = ge[["game_key","release_date","genre","total_prize_usd","offline_prize_usd",
             "pct_offline_prize","total_players","total_tournaments"]].copy()

# 2) Merge base (mensual por juego) + histórico anual (por juego y año)
master = tg.merge(
    he_sel,
    on=["game_key","year"],
    how="left"
)

# 3) Añadir totales/metadata del juego (por game_key)
master = master.merge(
    ge_sel,
    on="game_key",
    how="left"
)

print("MASTER (sin filtrar):", master.shape)
display(master.head())
# Out:
# MASTER (sin filtrar): (48377, 24)
#    rank               game  month  year  hours_watched  hours_streamed  \
# 0     1  League of Legends      1  2016       94377226         1362044
# 1     1  League of Legends      1  2016       94377226         1362044
# 2     1  League of Legends      1  2016       94377226         1362044
# 3     1  League of Legends      1  2016       94377226         1362044
# 4     1  League of Legends      1  2016       94377226         1362044
#
#    peak_viewers  peak_channels  streamers  avg_viewers  ...  year_prize_usd  \
# 0        530270           2903     129172       127021  ...        50025.02
# 1        530270           2903     129172       127021  ...       239015.61
# 2        530270           2903     129172       127021  ...       299620.13
# 3        530270           2903     129172       127021  ...      1459231.04
# 4        530270           2903     129172       127021  ...       517405.11
#
#    year_players year_tournaments release_date  \
# 0          40.0              5.0       2009.0
# 1         174.0              9.0       2009.0
# 2         395.0             23.0       2009.0
# 3         561.0             24.0       2009.0
# 4         145.0             11.0       2009.0
#
#                              genre  total_prize_usd  offline_prize_usd  \
# 0  Multiplayer Online Battle Arena     1.135960e+08        98546688.28
# 1  Multiplayer Online Battle Arena     1.135960e+08        98546688.28
# 2  Multiplayer Online Battle Arena     1.135960e+08        98546688.28
# 3  Multiplayer Online Battle Arena     1.135960e+08        98546688.28
# 4  Multiplayer Online Battle Arena     1.135960e+08        98546688.28
#
#    pct_offline_prize total_players  total_tournaments
# 0           0.867519        9588.0             3000.0
# 1           0.867519        9588.0             3000.0
# 2           0.867519        9588.0             3000.0
# 3           0.867519        9588.0             3000.0
# 4           0.867519        9588.0             3000.0
#
# [5 rows x 24 columns]

# %%
master[master['total_prize_usd'].isnull()]
# Out:
#        rank                            game  month  year  hours_watched  \
# 63        8               Z1: Battle Royale      1  2016        7894571
# 64        9           Talk Shows & Podcasts      1  2016        7688369
# 85       12                      Diablo III      1  2016        6235668
# 86       13                         Destiny      1  2016        5892573
# 93       16  Tom Clancy's Rainbow Six Siege      1  2016        4866039
# ...     ...                             ...    ...   ...            ...
# 48372   196   PokÃ©mon HeartGold/SoulSilver      9  2024         683902
# 48373   197                        Grounded      9  2024         683226
# 48374   198                 Ragnarok Online      9  2024         679965
# 48375   199                        Politics      9  2024         673799
# 48376   200                  DARK SOULS III      9  2024         667767
#
#        hours_streamed  peak_viewers  peak_channels  streamers  avg_viewers  \
# 63             205569         41588            460      21396        10625
# 64              53235         84051            148      10779        10347
# 85             218490         57383           2185      25458         8392
# 86             551615         18783           1741      60340         7930
# 93             242134         25742            694      42244         6549
# ...               ...           ...            ...        ...          ...
# 48372           10093         10600             42       1443          951
# 48373           37779         39473            116       7076          950
# 48374           28491          2539             75       1066          945
# 48375           16675         19746            210        957          937
# 48376           47190         13288            139       7886          928
#
#        ...  year_prize_usd  year_players year_tournaments release_date  genre  \
# 63     ...             NaN           NaN              NaN          NaN    NaN
# 64     ...             NaN           NaN              NaN          NaN    NaN
# 85     ...             NaN           NaN              NaN          NaN    NaN
# 86     ...             NaN           NaN              NaN          NaN    NaN
# 93     ...             NaN           NaN              NaN          NaN    NaN
# ...    ...             ...           ...              ...          ...    ...
# 48372  ...             NaN           NaN              NaN          NaN    NaN
# 48373  ...             NaN           NaN              NaN          NaN    NaN
# 48374  ...             NaN           NaN              NaN          NaN    NaN
# 48375  ...             NaN           NaN              NaN          NaN    NaN
# 48376  ...             NaN           NaN              NaN          NaN    NaN
#
#        total_prize_usd  offline_prize_usd  pct_offline_prize total_players  \
# 63                 NaN                NaN                NaN           NaN
# 64                 NaN                NaN                NaN           NaN
# 85                 NaN                NaN                NaN           NaN
# 86                 NaN                NaN                NaN           NaN
# 93                 NaN                NaN                NaN           NaN
# ...                ...                ...                ...           ...
# 48372              NaN                NaN                NaN           NaN
# 48373              NaN                NaN                NaN           NaN
# 48374              NaN                NaN                NaN           NaN
# 48375              NaN                NaN                NaN           NaN
# 48376              NaN                NaN                NaN           NaN
#
#        total_tournaments
# 63                   NaN
# 64                   NaN
# 85                   NaN
# 86                   NaN
# 93                   NaN
# ...                  ...
# 48372                NaN
# 48373                NaN
# 48374                NaN
# 48375                NaN
# 48376                NaN
#
# [15253 rows x 24 columns]

# %%
import re
import unicodedata

def normaliza_nombre(col):
    """Convierte nombres de columna a snake_case sin acentos ni espacios raros."""
    col = str(col)
    col = unicodedata.normalize("NFKD", col).encode("ascii", "ignore").decode("ascii")  # elimina acentos
    col = re.sub(r"[^\w\s]", "", col)  # quita símbolos
    col = re.sub(r"\s+", "_", col.strip().lower())  # snake_case
    return col

master.columns = [normaliza_nombre(c) for c in master.columns]

print("✅ Columnas normalizadas:")
print(master.columns.tolist())
# Out:
# ✅ Columnas normalizadas:
# ['rank', 'game', 'month', 'year', 'hours_watched', 'hours_streamed', 'peak_viewers', 'peak_channels', 'streamers', 'avg_viewers', 'avg_channels', 'avg_viewer_ratio', 'game_key', 'year_month', 'year_prize_usd', 'year_players', 'year_tournaments', 'release_date', 'genre', 'total_prize_usd', 'offline_prize_usd', 'pct_offline_prize', 'total_players', 'total_tournaments']

# %%
print("\n🔍 Columnas tipo object con ejemplos:")
for col in master.columns:
    if master[col].dtype == "object":
        muestra = master[col].dropna().astype(str).head(5).tolist()
        print(f"- {col}: ejemplo → {muestra}")
# Out:
# 🔍 Columnas tipo object con ejemplos:
# - game: ejemplo → ['League of Legends', 'League of Legends', 'League of Legends', 'League of Legends', 'League of Legends']
# - game_key: ejemplo → ['league of legends', 'league of legends', 'league of legends', 'league of legends', 'league of legends']
# - genre: ejemplo → ['Multiplayer Online Battle Arena', 'Multiplayer Online Battle Arena', 'Multiplayer Online Battle Arena', 'Multiplayer Online Battle Arena', 'Multiplayer Online Battle Arena']

# %%
for col in master.columns:
    if master[col].dtype == "object":
        try:
            master[col] = pd.to_numeric(master[col]
                                        .astype(str)
                                        .str.replace(",", "")
                                        .str.replace("%", ""),
                                        errors="ignore")
        except Exception as e:
            pass
# Out:
# C:\Users\cubea\AppData\Local\Temp\ipykernel_26804\2713837273.py:4: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   master[col] = pd.to_numeric(master[col]
# C:\Users\cubea\AppData\Local\Temp\ipykernel_26804\2713837273.py:4: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   master[col] = pd.to_numeric(master[col]
# C:\Users\cubea\AppData\Local\Temp\ipykernel_26804\2713837273.py:4: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   master[col] = pd.to_numeric(master[col]

# %%
cols_keep = [
    "game", "game_key", "year", "month", "year_month",
    "hours_watched", "avg_viewers", "peak_viewers", "streamers",
    "year_prize_usd", "year_players", "year_tournaments",
    "genre", "total_prize_usd", "total_players", "total_tournaments"
]

final = master[cols_keep].copy()
print("✅ Dataset reducido a columnas esenciales:", final.shape)
display(final.head())
# Out:
# ✅ Dataset reducido a columnas esenciales: (48377, 16)
#                 game           game_key  year  month year_month  \
# 0  League of Legends  league of legends  2016      1 2016-01-01
# 1  League of Legends  league of legends  2016      1 2016-01-01
# 2  League of Legends  league of legends  2016      1 2016-01-01
# 3  League of Legends  league of legends  2016      1 2016-01-01
# 4  League of Legends  league of legends  2016      1 2016-01-01
#
#    hours_watched  avg_viewers  peak_viewers  streamers  year_prize_usd  \
# 0       94377226       127021        530270     129172        50025.02
# 1       94377226       127021        530270     129172       239015.61
# 2       94377226       127021        530270     129172       299620.13
# 3       94377226       127021        530270     129172      1459231.04
# 4       94377226       127021        530270     129172       517405.11
#
#    year_players  year_tournaments                            genre  \
# 0          40.0               5.0  Multiplayer Online Battle Arena
# 1         174.0               9.0  Multiplayer Online Battle Arena
# 2         395.0              23.0  Multiplayer Online Battle Arena
# 3         561.0              24.0  Multiplayer Online Battle Arena
# 4         145.0              11.0  Multiplayer Online Battle Arena
#
#    total_prize_usd  total_players  total_tournaments
# 0     1.135960e+08         9588.0             3000.0
# 1     1.135960e+08         9588.0             3000.0
# 2     1.135960e+08         9588.0             3000.0
# 3     1.135960e+08         9588.0             3000.0
# 4     1.135960e+08         9588.0             3000.0

# %%
# A) Duplicados EXACTOS (todas las columnas idénticas)
print("Duplicados exactos en master:", master.duplicated().sum())

# B) Duplicados por CLAVE (game_key, year, month) en cada DF
print("tg dups por clave:", tg.duplicated(["game_key","year","month"]).sum())
print("he dups por clave:", he.duplicated(["game_key","year"]).sum())
print("ge dups por clave:", ge.duplicated(["game_key"]).sum())
print("master dups por clave:", master.duplicated(["game_key","year","month"]).sum())

# C) Si quieres ver cuáles son (top 10)
dups_master = (master[master.duplicated(["game_key","year","month"], keep=False)]
               .sort_values(["game_key","year","month"]))
display(dups_master.head(20))
# Out:
# Duplicados exactos en master: 467
# tg dups por clave: 11
# he dups por clave: 8024
# ge dups por clave: 1
# master dups por clave: 27388
#       rank               game  month  year  hours_watched  hours_streamed  \
# 345    142     Age of Empires      1  2016         248884             232
# 346    142     Age of Empires      1  2016         248884             232
# 347    142     Age of Empires      1  2016         248884             232
# 348    142     Age of Empires      1  2016         248884             232
# 349    142     Age of Empires      1  2016         248884             232
# 350    142     Age of Empires      1  2016         248884             232
# 351    142     Age of Empires      1  2016         248884             232
# 791    167  Age of Empires II      2  2016         129101            3169
# 792    167  Age of Empires II      2  2016         129101            3169
# 793    167  Age of Empires II      2  2016         129101            3169
# 794    167  Age of Empires II      2  2016         129101            3169
# 795    167  Age of Empires II      2  2016         129101            3169
# 796    167  Age of Empires II      2  2016         129101            3169
# 797    167  Age of Empires II      2  2016         129101            3169
# 798    167  Age of Empires II      2  2016         129101            3169
# 799    167  Age of Empires II      2  2016         129101            3169
# 800    167  Age of Empires II      2  2016         129101            3169
# 801    167  Age of Empires II      2  2016         129101            3169
# 802    167  Age of Empires II      2  2016         129101            3169
# 1258   193  Age of Empires II      3  2016          98903            2928
#
#       peak_viewers  peak_channels  streamers  avg_viewers  ...  \
# 345         107455             18         40          334  ...
# 346         107455             18         40          334  ...
# 347         107455             18         40          334  ...
# 348         107455             18         40          334  ...
# 349         107455             18         40          334  ...
# 350         107455             18         40          334  ...
# 351         107455             18         40          334  ...
# 791           1980             14        215          185  ...
# 792           1980             14        215          185  ...
# 793           1980             14        215          185  ...
# 794           1980             14        215          185  ...
# 795           1980             14        215          185  ...
# 796           1980             14        215          185  ...
# 797           1980             14        215          185  ...
# 798           1980             14        215          185  ...
# 799           1980             14        215          185  ...
# 800           1980             14        215          185  ...
# 801           1980             14        215          185  ...
# 802           1980             14        215          185  ...
# 1258           967             13        204          133  ...
#
#       year_prize_usd  year_players year_tournaments release_date     genre  \
# 345          5148.00          23.0              4.0       1997.0  Strategy
# 346          2684.00          24.0              3.0       1997.0  Strategy
# 347         32409.00          43.0              8.0       1997.0  Strategy
# 348           817.00           3.0              1.0       1997.0  Strategy
# 349         16425.00          60.0              4.0       1997.0  Strategy
# 350          4144.80          12.0              1.0       1997.0  Strategy
# 351          2420.00          16.0              1.0       1997.0  Strategy
# 791           320.00           9.0              2.0       1999.0  Strategy
# 792          3535.00          16.0              3.0       1999.0  Strategy
# 793           620.00           6.0              2.0       1999.0  Strategy
# 794          7555.11          38.0              5.0       1999.0  Strategy
# 795           630.00           9.0              3.0       1999.0  Strategy
# 796          1075.00           5.0              2.0       1999.0  Strategy
# 797          4750.00          27.0              6.0       1999.0  Strategy
# 798           100.00           2.0              1.0       1999.0  Strategy
# 799           200.00           2.0              1.0       1999.0  Strategy
# 800         30861.00          79.0              4.0       1999.0  Strategy
# 801          1660.56           7.0              2.0       1999.0  Strategy
# 802          5084.47          30.0             10.0       1999.0  Strategy
# 1258          320.00           9.0              2.0       1999.0  Strategy
#
#       total_prize_usd  offline_prize_usd  pct_offline_prize total_players  \
# 345         736284.75          522378.17           0.709478         624.0
# 346         736284.75          522378.17           0.709478         624.0
# 347         736284.75          522378.17           0.709478         624.0
# 348         736284.75          522378.17           0.709478         624.0
# 349         736284.75          522378.17           0.709478         624.0
# 350         736284.75          522378.17           0.709478         624.0
# 351         736284.75          522378.17           0.709478         624.0
# 791        3898508.73         1361409.22           0.349213        2256.0
# 792        3898508.73         1361409.22           0.349213        2256.0
# 793        3898508.73         1361409.22           0.349213        2256.0
# 794        3898508.73         1361409.22           0.349213        2256.0
# 795        3898508.73         1361409.22           0.349213        2256.0
# 796        3898508.73         1361409.22           0.349213        2256.0
# 797        3898508.73         1361409.22           0.349213        2256.0
# 798        3898508.73         1361409.22           0.349213        2256.0
# 799        3898508.73         1361409.22           0.349213        2256.0
# 800        3898508.73         1361409.22           0.349213        2256.0
# 801        3898508.73         1361409.22           0.349213        2256.0
# 802        3898508.73         1361409.22           0.349213        2256.0
# 1258       3898508.73         1361409.22           0.349213        2256.0
#
#       total_tournaments
# 345               341.0
# 346               341.0
# 347               341.0
# 348               341.0
# 349               341.0
# 350               341.0
# 351               341.0
# 791              1939.0
# 792              1939.0
# 793              1939.0
# 794              1939.0
# 795              1939.0
# 796              1939.0
# 797              1939.0
# 798              1939.0
# 799              1939.0
# 800              1939.0
# 801              1939.0
# 802              1939.0
# 1258             1939.0
#
# [20 rows x 24 columns]

# %%
he_agg = (he.groupby(["game_key","year"], as_index=False)
            .agg({"year_prize_usd":"sum",
                  "year_players":"sum",
                  "year_tournaments":"sum"}))
print("he_agg shape:", he_agg.shape)
# Out:
# he_agg shape: (2215, 5)

# %%
ge_agg = (ge.sort_values("total_prize_usd", ascending=False)
            .drop_duplicates(subset=["game_key"], keep="first"))
print("ge_agg shape:", ge_agg.shape)
# Out:
# ge_agg shape: (668, 9)

# %%
he_sel = he_agg[["game_key","year","year_prize_usd","year_players","year_tournaments"]]
ge_sel = ge_agg[["game_key","release_date","genre","total_prize_usd","offline_prize_usd",
                 "pct_offline_prize","total_players","total_tournaments"]]

master = (tg.merge(he_sel, on=["game_key","year"], how="left")
            .merge(ge_sel, on="game_key", how="left"))

print("MASTER (tras sanar fuentes):", master.shape)
print("Duplicados por clave en master:", master.duplicated(["game_key","year","month"]).sum())
# Out:
# MASTER (tras sanar fuentes): (21000, 24)
# Duplicados por clave en master: 11

# %%
master = (master
          .sort_values(["game_key","year","month"])
          .drop_duplicates(["game_key","year","month"], keep="first")
          .reset_index(drop=True))

print("Duplicados por clave en master (final):", master.duplicated(["game_key","year","month"]).sum())
# Out:
# Duplicados por clave en master (final): 0

# %%
final = master[(master["year"] >= 2016) & (master["year"] <= 2024)].copy()
print("FINAL 2016–2024:", final.shape)
# Out:
# FINAL 2016–2024: (20989, 24)

# %%
print(final.columns.tolist())
# Out:
# ['rank', 'game', 'month', 'year', 'hours_watched', 'hours_streamed', 'peak_viewers', 'peak_channels', 'streamers', 'avg_viewers', 'avg_channels', 'avg_viewer_ratio', 'game_key', 'year_month', 'year_prize_usd', 'year_players', 'year_tournaments', 'release_date', 'genre', 'total_prize_usd', 'offline_prize_usd', 'pct_offline_prize', 'total_players', 'total_tournaments']

# %%
# Orden lógico recomendado (respetando tus 23 columnas)
prefer = [
    "game", "game_key", "genre", "release_date",   # identidad / metadatos
    "year", "month", "year_month",                 # tiempo
    # Popularidad (Twitch, mensual)
    "hours_watched", "avg_viewers", "peak_viewers", "streamers",
    "hours_streamed", "avg_channels", "peak_channels", "avg_viewer_ratio",
    # Competitividad (Esports)
    "year_prize_usd", "year_players", "year_tournaments",
    # Totales históricos del juego
    "total_prize_usd", "offline_prize_usd", "pct_offline_prize",
    "total_players", "total_tournaments",
    # Extras
    "rank"
]

left = [c for c in prefer if c in final.columns]
right = [c for c in final.columns if c not in left]
final = final[left + right].copy()

print(final.columns.tolist()[:12], "...")
display(final.head(5))
# Out:
# ['game', 'game_key', 'genre', 'release_date', 'year', 'month', 'year_month', 'hours_watched', 'avg_viewers', 'peak_viewers', 'streamers', 'hours_streamed'] ...
#                       game                 game_key genre  release_date  year  \
# 0  .hack//G.U. Last Recode  .hack//g.u. last recode   NaN           NaN  2017
# 1     20 Minutes Till Dawn     20 minutes till dawn   NaN           NaN  2022
# 2                     2XKO                     2xko   NaN           NaN  2024
# 3              60 Parsecs!              60 parsecs!   NaN           NaN  2018
# 4              60 Seconds!              60 seconds!   NaN           NaN  2016
#
#    month year_month  hours_watched  avg_viewers  peak_viewers  ...  \
# 0     11 2017-11-01         145350          202          1222  ...
# 1      6 2022-06-01         911356         1267         29743  ...
# 2      8 2024-08-01        2137305         2876         60961  ...
# 3      9 2018-09-01         529688          736         31960  ...
# 4      7 2016-07-01         268754          361         32505  ...
#
#    avg_viewer_ratio  year_prize_usd  year_players  year_tournaments  \
# 0              4.12             NaN           NaN               NaN
# 1             74.38             NaN           NaN               NaN
# 2             66.91             NaN           NaN               NaN
# 3            283.71             NaN           NaN               NaN
# 4            450.17             NaN           NaN               NaN
#
#    total_prize_usd  offline_prize_usd  pct_offline_prize  total_players  \
# 0              NaN                NaN                NaN            NaN
# 1              NaN                NaN                NaN            NaN
# 2              NaN                NaN                NaN            NaN
# 3              NaN                NaN                NaN            NaN
# 4              NaN                NaN                NaN            NaN
#
#    total_tournaments  rank
# 0                NaN   199
# 1                NaN   159
# 2                NaN    94
# 3                NaN   109
# 4                NaN   126
#
# [5 rows x 24 columns]

# %%
# Chequeo de duplicados por clave
dups = final.duplicated(["game_key", "year", "month"]).sum()
print("Duplicados por clave (game_key, year, month):", dups)

# Si hubiera, nos quedamos con la primera ocurrencia (conservador)
if dups > 0:
    final = (final
             .sort_values(["game_key","year","month"])
             .drop_duplicates(["game_key","year","month"], keep="first")
             .reset_index(drop=True))
    print("Duplicados eliminados. Nuevo shape:", final.shape)
# Out:
# Duplicados por clave (game_key, year, month): 0

# %%
def filtra(df, juego=None, genero=None, desde=None, hasta=None, con_premios=None):
    x = df.copy()
    if juego:
        x = x[x["game"].str.lower() == juego.lower()]
    if genero:
        x = x[x["genre"].str.lower() == genero.lower()]
    if desde:
        x = x[x["year"] >= int(desde)]
    if hasta:
        x = x[x["year"] <= int(hasta)]
    if con_premios is True:
        x = x[x["year_prize_usd"].notna()]
    if con_premios is False:
        x = x[x["year_prize_usd"].isna()]
    return x

# ejemplos:
display(filtra(final, juego="League of Legends").head(3))
display(filtra(final, genero="MOBA", desde=2020, con_premios=True).head(3))
# Out:
#                    game           game_key                            genre  \
# 9223  League of Legends  league of legends  Multiplayer Online Battle Arena
# 9224  League of Legends  league of legends  Multiplayer Online Battle Arena
# 9225  League of Legends  league of legends  Multiplayer Online Battle Arena
#
#       release_date  year  month year_month  hours_watched  avg_viewers  \
# 9223        2009.0  2016      1 2016-01-01       94377226       127021
# 9224        2009.0  2016      2 2016-02-01       93154772       134035
# 9225        2009.0  2016      3 2016-03-01       94514511       127206
#
#       peak_viewers  ...  avg_viewer_ratio  year_prize_usd  year_players  \
# 9223        530270  ...             69.29     10519032.01        3155.0
# 9224        475784  ...             73.54     10519032.01        3155.0
# 9225        599114  ...             74.77     10519032.01        3155.0
#
#       year_tournaments  total_prize_usd  offline_prize_usd  pct_offline_prize  \
# 9223             182.0     1.135960e+08        98546688.28           0.867519
# 9224             182.0     1.135960e+08        98546688.28           0.867519
# 9225             182.0     1.135960e+08        98546688.28           0.867519
#
#       total_players  total_tournaments  rank
# 9223         9588.0             3000.0     1
# 9224         9588.0             3000.0     1
# 9225         9588.0             3000.0     1
#
# [3 rows x 24 columns]
# Empty DataFrame
# Columns: [game, game_key, genre, release_date, year, month, year_month, hours_watched, avg_viewers, peak_viewers, streamers, hours_streamed, avg_channels, peak_channels, avg_viewer_ratio, year_prize_usd, year_players, year_tournaments, total_prize_usd, offline_prize_usd, pct_offline_prize, total_players, total_tournaments, rank]
# Index: []
#
# [0 rows x 24 columns]

# %%
from pathlib import Path

# Ruta destino: carpeta /data/processed (una arriba del notebook)
OUT_DIR = Path.cwd().parent / "data" / "processed"
OUT_DIR.mkdir(parents=True, exist_ok=True)  # crea la carpeta si no existe

# Nombre claro para la versión final
out_path = OUT_DIR / "esports_occidente_master_2016_2024_FINAL.csv"

# Guardamos el CSV
final.to_csv(out_path, index=False, encoding="utf-8")

print(f"✅ Dataset guardado correctamente en:\n{out_path}")
print(f"Shape: {final.shape[0]:,} filas × {final.shape[1]} columnas")
# Out:
# ✅ Dataset guardado correctamente en:
# c:\Users\cubea\OneDrive\Escritorio\project_esports_occidente\notebooks\data\processed\esports_occidente_master_2016_2024_FINAL.csv
# Shape: 20,989 filas × 24 columnas

# %%
final_esports = final[final["year_prize_usd"].notna()].copy()
print(final_esports.shape)
# Out:
# (4201, 24)

# %%
juegos_esports = final_esports["game_key"].nunique()
print(f"🎮 Juegos eSports únicos: {juegos_esports}")
# Out:
# 🎮 Juegos eSports únicos: 191

# %%
print("Shape:", final_esports.shape)
final_esports.info()
# Out:
# Shape: (4201, 24)
# <class 'pandas.core.frame.DataFrame'>
# Index: 4201 entries, 154 to 20879
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   game               4201 non-null   object
#  1   game_key           4201 non-null   object
#  2   genre              4201 non-null   object
#  3   release_date       4201 non-null   float64
#  4   year               4201 non-null   int64
#  5   month              4201 non-null   int64
#  6   year_month         4201 non-null   datetime64[ns]
#  7   hours_watched      4201 non-null   int64
#  8   avg_viewers        4201 non-null   int64
#  9   peak_viewers       4201 non-null   int64
#  10  streamers          4201 non-null   int64
#  11  hours_streamed     4201 non-null   int64
#  12  avg_channels       4201 non-null   int64
#  13  peak_channels      4201 non-null   int64
#  14  avg_viewer_ratio   4201 non-null   float64
#  15  year_prize_usd     4201 non-null   float64
#  16  year_players       4201 non-null   float64
#  17  year_tournaments   4201 non-null   float64
#  18  total_prize_usd    4178 non-null   float64
#  19  offline_prize_usd  4180 non-null   float64
#  20  pct_offline_prize  4201 non-null   float64
#  21  total_players      4201 non-null   float64
#  22  total_tournaments  4201 non-null   float64
#  23  rank               4201 non-null   int64
# dtypes: datetime64[ns](1), float64(10), int64(10), object(3)
# memory usage: 820.5+ KB

# %%
pd.set_option("display.max_columns", None)  # para ver todas las columnas
display(final_esports.head(10))
# Out:
#                   game           game_key     genre  release_date  year  \
# 154     Age of Empires     age of empires  Strategy        1997.0  2016
# 155  Age of Empires II  age of empires ii  Strategy        1999.0  2016
# 156  Age of Empires II  age of empires ii  Strategy        1999.0  2016
# 157  Age of Empires II  age of empires ii  Strategy        1999.0  2016
# 158  Age of Empires II  age of empires ii  Strategy        1999.0  2016
# 159  Age of Empires II  age of empires ii  Strategy        1999.0  2016
# 160  Age of Empires II  age of empires ii  Strategy        1999.0  2016
# 161  Age of Empires II  age of empires ii  Strategy        1999.0  2016
# 162  Age of Empires II  age of empires ii  Strategy        1999.0  2016
# 163  Age of Empires II  age of empires ii  Strategy        1999.0  2016
#
#      month year_month  hours_watched  avg_viewers  peak_viewers  streamers  \
# 154      1 2016-01-01         248884          334        107455         40
# 155      2 2016-02-01         129101          185          1980        215
# 156      3 2016-03-01          98903          133           967        204
# 157      4 2016-04-01         116800          162          1412        208
# 158      5 2016-05-01          93519          125           750        250
# 159      6 2016-06-01         107624          149          7631        236
# 160      8 2016-08-01         117560          158          1284        224
# 161      9 2016-09-01         158921          221          4629        237
# 162     10 2016-10-01         166279          223          2369        274
# 163     11 2016-11-01         201024          279          2414        254
#
#      hours_streamed  avg_channels  peak_channels  avg_viewer_ratio  \
# 154             232             0             18           1072.78
# 155            3169             4             14             40.74
# 156            2928             3             13             33.78
# 157            2923             4             13             39.96
# 158            3204             4             13             29.19
# 159            2896             4             14             37.16
# 160            3446             4             14             34.11
# 161            3356             4             15             47.35
# 162            3883             5             17             42.82
# 163            4477             6             18             44.90
#
#      year_prize_usd  year_players  year_tournaments  total_prize_usd  \
# 154        64047.80         181.0              22.0        736284.75
# 155        56391.14         230.0              41.0       3898508.73
# 156        56391.14         230.0              41.0       3898508.73
# 157        56391.14         230.0              41.0       3898508.73
# 158        56391.14         230.0              41.0       3898508.73
# 159        56391.14         230.0              41.0       3898508.73
# 160        56391.14         230.0              41.0       3898508.73
# 161        56391.14         230.0              41.0       3898508.73
# 162        56391.14         230.0              41.0       3898508.73
# 163        56391.14         230.0              41.0       3898508.73
#
#      offline_prize_usd  pct_offline_prize  total_players  total_tournaments  \
# 154          522378.17           0.709478          624.0              341.0
# 155         1361409.22           0.349213         2256.0             1939.0
# 156         1361409.22           0.349213         2256.0             1939.0
# 157         1361409.22           0.349213         2256.0             1939.0
# 158         1361409.22           0.349213         2256.0             1939.0
# 159         1361409.22           0.349213         2256.0             1939.0
# 160         1361409.22           0.349213         2256.0             1939.0
# 161         1361409.22           0.349213         2256.0             1939.0
# 162         1361409.22           0.349213         2256.0             1939.0
# 163         1361409.22           0.349213         2256.0             1939.0
#
#      rank
# 154   142
# 155   167
# 156   193
# 157   184
# 158   199
# 159   178
# 160   192
# 161   133
# 162   163
# 163   132

# %%
cols_keep = [
    "game", "genre", "year", "month", "year_month",
    "hours_watched", "avg_viewers", "peak_viewers",
    "year_prize_usd", "year_players", "year_tournaments",
    "total_prize_usd", "total_players", "total_tournaments"
]

final_esports_clean = final_esports[cols_keep].copy()

print("✅ Dataset de eSports reducido a columnas esenciales:", final_esports_clean.shape)
display(final_esports_clean.head(5))
# Out:
# ✅ Dataset de eSports reducido a columnas esenciales: (4201, 14)
#                   game     genre  year  month year_month  hours_watched  \
# 154     Age of Empires  Strategy  2016      1 2016-01-01         248884
# 155  Age of Empires II  Strategy  2016      2 2016-02-01         129101
# 156  Age of Empires II  Strategy  2016      3 2016-03-01          98903
# 157  Age of Empires II  Strategy  2016      4 2016-04-01         116800
# 158  Age of Empires II  Strategy  2016      5 2016-05-01          93519
#
#      avg_viewers  peak_viewers  year_prize_usd  year_players  \
# 154          334        107455        64047.80         181.0
# 155          185          1980        56391.14         230.0
# 156          133           967        56391.14         230.0
# 157          162          1412        56391.14         230.0
# 158          125           750        56391.14         230.0
#
#      year_tournaments  total_prize_usd  total_players  total_tournaments
# 154              22.0        736284.75          624.0              341.0
# 155              41.0       3898508.73         2256.0             1939.0
# 156              41.0       3898508.73         2256.0             1939.0
# 157              41.0       3898508.73         2256.0             1939.0
# 158              41.0       3898508.73         2256.0             1939.0

# %%
final_esports_clean.info
# Out:
# <bound method DataFrame.info of                        game                  genre  year  month year_month  \
# 154          Age of Empires               Strategy  2016      1 2016-01-01
# 155       Age of Empires II               Strategy  2016      2 2016-02-01
# 156       Age of Empires II               Strategy  2016      3 2016-03-01
# 157       Age of Empires II               Strategy  2016      4 2016-04-01
# 158       Age of Empires II               Strategy  2016      5 2016-05-01
# ...                     ...                    ...   ...    ...        ...
# 20875  Yu-Gi-Oh! Duel Links  Collectible Card Game  2019      8 2019-08-01
# 20876  Yu-Gi-Oh! Duel Links  Collectible Card Game  2019      9 2019-09-01
# 20877  Yu-Gi-Oh! Duel Links  Collectible Card Game  2019     10 2019-10-01
# 20878  Yu-Gi-Oh! Duel Links  Collectible Card Game  2019     11 2019-11-01
# 20879  Yu-Gi-Oh! Duel Links  Collectible Card Game  2019     12 2019-12-01
#
#        hours_watched  avg_viewers  peak_viewers  year_prize_usd  year_players  \
# 154           248884          334        107455        64047.80         181.0
# 155           129101          185          1980        56391.14         230.0
# 156            98903          133           967        56391.14         230.0
# 157           116800          162          1412        56391.14         230.0
# 158            93519          125           750        56391.14         230.0
# ...              ...          ...           ...             ...           ...
# 20875         329730          443          4211           20.00           1.0
# 20876         416912          579          7604           20.00           1.0
# 20877         428887          577          3752           20.00           1.0
# 20878         333232          463          2825           20.00           1.0
# 20879         310418          417          2358           20.00           1.0
#
#        year_tournaments  total_prize_usd  total_players  total_tournaments
# 154                22.0        736284.75          624.0              341.0
# 155                41.0       3898508.73         2256.0             1939.0
# 156                41.0       3898508.73         2256.0             1939.0
# 157                41.0       3898508.73         2256.0             1939.0
# 158                41.0       3898508.73         2256.0             1939.0
# ...                 ...              ...            ...                ...
# 20875               1.0         48746.72          328.0              219.0
# 20876               1.0         48746.72          328.0              219.0
# 20877               1.0         48746.72          328.0              219.0
# 20878               1.0         48746.72          328.0              219.0
# 20879               1.0         48746.72          328.0              219.0
#
# [4201 rows x 14 columns]>
